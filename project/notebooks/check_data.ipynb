# %%
import pandas as pd 
import sys

# %%
df = pd.read_excel("../data/processed/patient_level_summary.xlsx")
df.head()
# Out:
#    patientID Diagnosis group at enrollment Biological category Apoe4 status  \
# 0          1                      Dementia                  AD        E2/E3
# 1          2                      Dementia              non-AD        E3/E3
# 2          3                           MCI              non-AD        E3/E3
# 3          4                           MCI                  AD        E4/E4
# 4          5                      Dementia                  AD        E3/E3
#
#    Gender  Age at first MMSE  Education   HT   DM  Hyperlipidemia  ...  \
# 0       0                 79          0  0.0  1.0             1.0  ...
# 1       1                 51         12  0.0  1.0             0.0  ...
# 2       1                 47          9  1.0  0.0             1.0  ...
# 3       0                 82          8  0.0  1.0             1.0  ...
# 4       0                 72          2  0.0  1.0             1.0  ...
#
#    MMSE Repeat no._final MMSE Date_final  MMSE_final  CDR Repeat_first  \
# ...

# %%
df.columns
# Out:
# Index(['patientID', 'Diagnosis group at enrollment', 'Biological category',
#        'Apoe4 status', 'Gender', 'Age at first MMSE', 'Education', 'HT', 'DM',
#        'Hyperlipidemia', 'age_of_onset', 'MMSE Date_first', 'MMSE_first',
#        'MMSE Repeat no._final', 'MMSE Date_final', 'MMSE_final',
#        'CDR Repeat_first', 'CDR Date_first', 'CDR_first', 'CDR Repeat_next',
#        'CDR Date_next', 'CDR_next', 'event'],
#       dtype='object')

# %%
df2 = pd.read_excel("../data/processed/patient_level_summary.xlsx", sheet_name="Sheet1")
